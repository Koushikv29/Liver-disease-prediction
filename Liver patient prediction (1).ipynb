# %% [markdown]
# ## $$ Data \ Analysis \ and \ prediction \ of \ Liver patients$$

# %% [markdown]
# # **Problem statement**

# %% [markdown]
# Patients with Liver disease have been continuously increasing because of excessive consumption of
# alcohol, inhale of harmful gases, intake of contaminated food, pickles and drugs. This dataset was
# used to evaluate prediction algorithms in an effort to reduce burden on doctors. We are using classification techniques to predict whether a person has liver disease or not.

# %% [markdown]
# Indian Liver Patient Dataset (ILPD).csv - Contains dataset of people having Liver disease or not having Liver disease.
#
# **Columns**:
#
# ● Age of the patient
#
# ● Gender of the patient
#
# ● Total Bilirubin
#
# ● Direct Bilirubin
#
# ● Alkaline Phosphotase
#
# ● Alamine Aminotransferase
#
# ● Aspartate Aminotransferase
#
# ● Total Protiens
#
# ● Albumin
#
# ● Albumin and Globulin Ratio
#
# ● Target
#
# **Bilirubin**- Bilirubin (bil-ih-ROO-bin) is a yellowish pigment that is made during the breakdown of red blood cells. Bilirubin passes through the liver. When bilirubin levels remain high for prolonged periods, it usually means there is severe liver disease and possibly cirrhosis. High levels of bilirubin can cause jaundice (yellowing of the skin and eyes, darker urine).
#
# **Total Bilirubin** - Total bilirubin is a combination of direct and indirect bilirubin. Typically, you'll get results for direct and total bilirubin. Typical results for a total bilirubin test are 1.2 milligrams per deciliter (mg/dL) for adults and usually 1 mg/dL for those under 18.
#
# **Direct Bilirubin** - Bilirubin attached by the liver to glucuronic acid, a glucose-derived acid, is called direct or conjugated, bilirubin. Bilirubin not attached to glucuronic acid is called indirect.
#
# **Alkaline Phosphotase** - Alkaline phosphatase (ALP) is an enzyme that is present in many parts of the body, but it is primarily found in the liver, bones, intestine, and kidneys. Alkaline phosphatase testing measures the amount of this enzyme in the blood.A high alk phos level does not reflect liver damage or inflammation. A high alk phos level occurs when there is buildup of pressure in the liver.
#
# **Alamine Aminotransferase** - Alanine Aminotransferase. Alanine aminotransferase (ALT) is an enzyme found mostly in liver cells. Apart from the liver, it is also found in heart and muscle cells. The function of ALT is to convert alanine into pyruvate, for cellular energy production.
#
# An ALT test result of >100 IU/l is a clear indicator of **serious liver disease**, but a mildly elevated ALT result (30–100 IU/l) is often ascribed to the use of medication (for example statins) or alcohol, obesity, or, for lower ALT levels (<50 IU/l), considered as part of the normal distribution of test results.
#
# **Aspartate Aminotransferase** - AST, or aspartate aminotransferase, is one of the two liver enzymes. It is also known as serum glutamic-oxaloacetic transaminase, or SGOT. AST is a protein made by liver cells. When liver cells are damaged, AST leaks out into the bloodstream and the level of AST in the blood becomes elevated.
#
# High levels of AST in the blood may indicate liver diseases
#
# **Total Protiens** - The total protein test measures the concentration of all the proteins in the plasma portion of your blood. Proteins are important building blocks of all cells and tissues; they are important for body growth and health. Total protein measures the combined amount of two types of proteins, albumin and globulin. Albumin moves many small molecules through the blood but its main purpose is to keep fluid from leaking out of blood vessels, while globulin proteins include enzymes, antibodies and more than 500 other proteins.
#
# The normal range is 6.0 to 8.3 grams per deciliter (g/dL) or 60 to 83 g/L.A high total protein level could indicate dehydration.
#
# **Albumin** - Albumin is a protein made by the liver. Albumin prevents fluid from leaking out of blood vessels into tissues.
#
# A normal albumin range is 3.4 to 5.4 g/dL. If you have a lower albumin level, you may have malnutrition. It can also mean that you have liver disease, kidney disease, or an inflammatory disease. Higher albumin levels may be caused by acute infections, burns, and stress from surgery or a heart attack.
#
# **Albumin and Globulin Ratio** - High A/G ratio: This can be a sign of disease in your liver, kidney.

# %% [markdown]
# ## ***Let's Begin !***

# %% [markdown]
# ## **1. Know your data and understand the variables**

# %% [markdown]
# #### Import basic libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# #### Load the data

# %%
data = pd.read_csv('Indian Liver Patient Dataset (ILPD).csv')

# %%
# Dataset first five rows
data.head()
# Out:
#    65 Female   0.7  0.1  187  16   18  6.8  3.3   0.9  1
# 0  62   Male  10.9  5.5  699  64  100  7.5  3.2  0.74  1
# 1  62   Male   7.3  4.1  490  60   68  7.0  3.3  0.89  1
# 2  58   Male   1.0  0.4  182  14   20  6.8  3.4  1.00  1
# 3  72   Male   3.9  2.0  195  27   59  7.3  2.4  0.40  1
# 4  46   Male   1.8  0.7  208  19   14  7.6  4.4  1.30  1

# %%
# Dataset last five rows
data.tail()
# Out:
#      65 Female  0.7  0.1  187  16  18  6.8  3.3   0.9  1
# 577  60   Male  0.5  0.1  500  20  34  5.9  1.6  0.37  2
# 578  40   Male  0.6  0.1   98  35  31  6.0  3.2  1.10  1
# 579  52   Male  0.8  0.2  245  48  49  6.4  3.2  1.00  1
# 580  31   Male  1.3  0.5  184  29  32  6.8  3.4  1.00  1
# 581  38   Male  1.0  0.3  216  21  24  7.3  4.4  1.50  2

# %% [markdown]
# **As you can see the column names are not proper and we have to give proper names to the columns**

# %%
# Changing column names
data.columns=['age','gender','Total_Bilirubin','Direct_Bilirubin','Alkaline_Phosphatase','Alanine_Aminotransferase','Aspartate_Aminotransferase',
            'Total_Protiens','Albumin','Albumin_and_Globulin_Ratio','Target']
data.head(20)
# Out:
#     age  gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphatase  \
# 0    62    Male             10.9               5.5                   699
# 1    62    Male              7.3               4.1                   490
# 2    58    Male              1.0               0.4                   182
# 3    72    Male              3.9               2.0                   195
# 4    46    Male              1.8               0.7                   208
# 5    26  Female              0.9               0.2                   154
# 6    29  Female              0.9               0.3                   202
# 7    17    Male              0.9               0.3                   202
# 8    55    Male              0.7               0.2                   290
# 9    57    Male              0.6               0.1                   210
# 10   72    Male              2.7               1.3                   260
# 11   64    Male              0.9               0.3                   310
# ...

# %%
## if score==negative, mark 0 ;else 1 
def partition(x):
    if x == 2:
        return 0
    return 1

data['Target'] = data['Target'].map(partition)

# %%
data.head(20)
# Out:
#     age  gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphatase  \
# 0    62    Male             10.9               5.5                   699
# 1    62    Male              7.3               4.1                   490
# 2    58    Male              1.0               0.4                   182
# 3    72    Male              3.9               2.0                   195
# 4    46    Male              1.8               0.7                   208
# 5    26  Female              0.9               0.2                   154
# 6    29  Female              0.9               0.3                   202
# 7    17    Male              0.9               0.3                   202
# 8    55    Male              0.7               0.2                   290
# 9    57    Male              0.6               0.1                   210
# 10   72    Male              2.7               1.3                   260
# 11   64    Male              0.9               0.3                   310
# ...

# %%
# Dataset rows and columns count
data.shape
# Out:
# (582, 11)

# %% [markdown]
# **There are 582 rows and 11 columns**

# %%
# Dataset info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         582 non-null    int64
#  1   gender                      582 non-null    object
#  2   Total_Bilirubin             582 non-null    float64
#  3   Direct_Bilirubin            582 non-null    float64
#  4   Alkaline_Phosphatase        582 non-null    int64
#  5   Alanine_Aminotransferase    582 non-null    int64
#  6   Aspartate_Aminotransferase  582 non-null    int64
#  7   Total_Protiens              582 non-null    float64
#  8   Albumin                     582 non-null    float64
#  9   Albumin_and_Globulin_Ratio  578 non-null    float64
#  10  Target                      582 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.1+ KB

# %% [markdown]
# **1. There are 4 null values found in Albumin_and_Globulin_Ratio and we have to deal with it**
#
# **2. There is 1 categorical column and 10 numerical columns**

# %%
# Dataset basic analysis
data.describe()
# Out:
#               age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphatase  \
# count  582.000000       582.000000        582.000000            582.000000
# mean    44.711340         3.303265          1.488488            290.754296
# std     16.181921         6.213926          2.810324            243.108929
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.250000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     57.750000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alanine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                582.000000                  582.000000      582.000000
# mean                  80.824742                  110.068729        6.482646
# ...

# %%
# Dataset basic analysis for object datatype
data.describe(include='O')
# Out:
#        gender
# count     582
# unique      2
# top      Male
# freq      441

# %% [markdown]
# ### Insights
# 1. People from age of 4-90 get liver disease, average being 44 years.
# 2. Total_Bilirubin ranges from 0.4-75, average being 3.30.
# 3. Direct_Bilirubin ranges from 0.10 - 19.70, average being 1.488.
# 4. Alkaline_Phosphatase ranges from 63-2110, average being 290.74.
# 5. Alanine_Aminotransferase	 ranges from 10-2000, average being 80.8.
# 6. Aspartate_Aminotransferase ranges from 10-4929, average being 110.
# 7. Total_Protiens ranges from 2.7-9.6, average being 6.4.
# 8. Albumin ranges from 0.90-5.50, average being 3.14.
# 9. Albumin_and_Globulin_Ratio ranges from 0.30-2.80, average being 0.94.
# 10. Out of 582, 441 are Males and rest are Females.

# %% [markdown]
# ### Handling Missing values

# %%
# Replacing null values with mean values
data['Albumin_and_Globulin_Ratio'].fillna(data['Albumin_and_Globulin_Ratio'].mean(),inplace = True)

# %%
# Rechecking count
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         582 non-null    int64
#  1   gender                      582 non-null    object
#  2   Total_Bilirubin             582 non-null    float64
#  3   Direct_Bilirubin            582 non-null    float64
#  4   Alkaline_Phosphatase        582 non-null    int64
#  5   Alanine_Aminotransferase    582 non-null    int64
#  6   Aspartate_Aminotransferase  582 non-null    int64
#  7   Total_Protiens              582 non-null    float64
#  8   Albumin                     582 non-null    float64
#  9   Albumin_and_Globulin_Ratio  582 non-null    float64
#  10  Target                      582 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.1+ KB

# %% [markdown]
# #### **We have successfully handled missing values**

# %% [markdown]
# ### **Domain analysis**

# %% [markdown]
# The dataset now contains **582 rows and 11 columns***
#
# The dataset has 11 columns in which 1 columns is categorical and 10 columns are numerical
#
# ### **Numerical columns**
#
# **Age** - Age of the patients.
#
# **Total Bilirubin** - Total bilirubin is a combination of direct and indirect bilirubin. Typically, you'll get results for direct and total bilirubin. Typical results for a total bilirubin test are 1.2 milligrams per deciliter (mg/dL) for adults and usually 1 mg/dL for those under 18.
#
# **Direct Bilirubin** - Bilirubin attached by the liver to glucuronic acid, a glucose-derived acid, is called direct or conjugated, bilirubin. Bilirubin not attached to glucuronic acid is called indirect.
#
# **Alkaline Phosphotase** - Alkaline phosphatase (ALP) is an enzyme that is present in many parts of the body, but it is primarily found in the liver, bones, intestine, and kidneys. Alkaline phosphatase testing measures the amount of this enzyme in the blood.A high alk phos level does not reflect liver damage or inflammation. A high alk phos level occurs when there is buildup of pressure in the liver.
#
# **Alamine Aminotransferase** - Alanine Aminotransferase. Alanine aminotransferase (ALT) is an enzyme found mostly in liver cells. Apart from the liver, it is also found in heart and muscle cells. The function of ALT is to convert alanine into pyruvate, for cellular energy production.
#
# An ALT test result of >100 IU/l is a clear indicator of serious liver disease, but a mildly elevated ALT result (30–100 IU/l) is often ascribed to the use of medication (for example statins) or alcohol, obesity, or, for lower ALT levels (<50 IU/l), considered as part of the normal distribution of test results.
#
# **Aspartate Aminotransferase** - AST, or aspartate aminotransferase, is one of the two liver enzymes. It is also known as serum glutamic-oxaloacetic transaminase, or SGOT. AST is a protein made by liver cells. When liver cells are damaged, AST leaks out into the bloodstream and the level of AST in the blood becomes elevated.
#
# High levels of AST in the blood may indicate liver diseases
#
# **Total Protiens** - The total protein test measures the concentration of all the proteins in the plasma portion of your blood. Proteins are important building blocks of all cells and tissues; they are important for body growth and health. Total protein measures the combined amount of two types of proteins, albumin and globulin. Albumin moves many small molecules through the blood but its main purpose is to keep fluid from leaking out of blood vessels, while globulin proteins include enzymes, antibodies and more than 500 other proteins.
#
# The normal range is 6.0 to 8.3 grams per deciliter (g/dL) or 60 to 83 g/L.A high total protein level could indicate dehydration.
#
# **Albumin** - Albumin is a protein made by the liver. Albumin prevents fluid from leaking out of blood vessels into tissues.
#
# A normal albumin range is 3.4 to 5.4 g/dL. If you have a lower albumin level, you may have malnutrition. It can also mean that you have liver disease, kidney disease, or an inflammatory disease. Higher albumin levels may be caused by acute infections, burns, and stress from surgery or a heart attack.
#
# **Albumin and Globulin Ratio** - High A/G ratio: This can be a sign of disease in your liver, kidney.
#
# ### **Categorical columns**
#
# **Gender** - Gender of the patients.

# %% [markdown]
# # **2. Data Visualization, Exploratory data analysis, Experimenting with charts**

# %% [markdown]
# 1. Univariate analysis
# 2. Bivariate analysis
# 3. Multivariate analysis

# %% [markdown]
# ### 1. **Univariate analysis**

# %%
plt.figure(figsize=(10,10),facecolor='white')
plotnumber=1
for column in data:
  if plotnumber<=11:
    ax=plt.subplot(4,3,plotnumber)
    sns.histplot(x=data[column],kde=True)
    plt.xlabel(column,fontsize=10)
    plt.ylabel('count',fontsize=10)
  plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### Insights
# 1. Age is normally distributed.
# 2. Rest all columns are not normally distributed.

# %%
# Checking frequency distribution of Gender column
plt.subplot(1,2,1)
colorz=['coral','teal']
sns.countplot(x=data.gender,palette=colorz)
#pie chart
plt.subplot(1,2,2)
labels = 'Male', 'Female'
sizes = data.gender.value_counts()
colors = ['coral','teal']
plt.pie(sizes, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True)
plt.axis('equal')
plt.title('Percentage of sex',fontsize=15)
plt.legend( labels, loc="best")
fig=plt.gcf()
fig.set_size_inches(10,4)
plt.plot()
plt.show()

# %% [markdown]
# ### Insights
# 1. Males are 75.8%
# 2. Females are 24.2%

# %% [markdown]
# ## **Bivariate analysis**

# %%
# Charges vs age
sns.countplot(data=data,x='age',hue='Target')
fig=plt.gcf()
fig.set_size_inches(30,4)

# %% [markdown]
# ### Insights
# * As Age increases the chances of getting Liver disease is higher.

# %%
# Analyse relationship between gender and Target
plt.figure(figsize=(6,2))
sns.countplot(data=data,x='gender',hue='Target')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# ### Insights
# * Male has higher chances of getting Liver disease than Female.

# %%
# Analyse relationship between Total_Bilirubin and Target
plt.figure(figsize=(25,2))
sns.countplot(data=data,x='Total_Bilirubin',hue='Target')
# Out:
# <AxesSubplot:xlabel='Total_Bilirubin', ylabel='count'>

# %% [markdown]
# ### Insights
# * Lesser the Total_Bilirubin higher the chances of getting Liver disease.

# %%
# Analyse relationship between Direct_Bilirubin and Target
plt.figure(figsize=(25,2))
sns.countplot(data=data,x='Direct_Bilirubin',hue='Target')
# Out:
# <AxesSubplot:xlabel='Direct_Bilirubin', ylabel='count'>

# %% [markdown]
# ### Insights
# * Lesser the Direct_Bilirubin higher the chances of getting Liver disease.

# %%
# Analyse relationship between Alkaline_Phosphatase and Target
plt.figure(figsize=(25,2))
sns.countplot(data=data,x='Alkaline_Phosphatase',hue='Target')
# Out:
# <AxesSubplot:xlabel='Alkaline_Phosphatase', ylabel='count'>

# %% [markdown]
# ### Insights
# * Higher the Alkaline_Phosphatase higher the chances of getting Liver disease.

# %%
# Analyse relationship between Alanine_Aminotransferase and Target
plt.figure(figsize=(25,2))
sns.histplot(data=data,x='Alanine_Aminotransferase',hue='Target')
# Out:
# <AxesSubplot:xlabel='Alanine_Aminotransferase', ylabel='Count'>

# %% [markdown]
# ### Insights
# * Lesser the Alanine_Aminotransferase higher the chances of getting Liver disease.

# %%
# Analyse relationship between Aspartate_Aminotransferase and Target
plt.figure(figsize=(25,2))
sns.histplot(data=data,x='Aspartate_Aminotransferase',hue='Target')
# Out:
# <AxesSubplot:xlabel='Aspartate_Aminotransferase', ylabel='Count'>

# %% [markdown]
# ### Insights
# * Lesser the Aspartate_Aminotransferase higher the chances of getting Liver disease.

# %%
# Analyse relationship between Total_Protiens and Target
plt.figure(figsize=(25,2))
sns.countplot(data=data,x='Total_Protiens',hue='Target')
# Out:
# <AxesSubplot:xlabel='Total_Protiens', ylabel='count'>

# %% [markdown]
# ### Insights
# * When total proteins are in range of 5-8.6 the patients are having high chances of getting liver disease.

# %%
# Analyse relationship between Albumin and Target
plt.figure(figsize=(25,2))
sns.countplot(data=data,x='Albumin',hue='Target')
# Out:
# <AxesSubplot:xlabel='Albumin', ylabel='count'>

# %% [markdown]
# ### Insights
# * when Albumin is in range from 1.5-5 People have chances of Liver disease.

# %%
# Analyse relationship between Albumin_and_Globulin_Ratio and Target
plt.figure(figsize=(25,2))
sns.histplot(data=data,x='Albumin_and_Globulin_Ratio',hue='Target')
# Out:
# <AxesSubplot:xlabel='Albumin_and_Globulin_Ratio', ylabel='Count'>

# %% [markdown]
# ### Insights
# * When the ratio is between 0-1.5 people have high chances of Liver disease

# %% [markdown]
# ## 3. **Feature Engineering and data preprocessing**

# %%
# checking for missing values
data.isnull().sum()
# Out:
# age                           0
# gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphatase          0
# Alanine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Target                        0
# dtype: int64

# %%
sns.boxplot(x=data.Total_Bilirubin)
# Out:
# <AxesSubplot:xlabel='Total_Bilirubin'>

# %%
sns.boxplot(x=data.Direct_Bilirubin)
# Out:
# <AxesSubplot:xlabel='Direct_Bilirubin'>

# %%
sns.boxplot(x=data.Alkaline_Phosphatase)
# Out:
# <AxesSubplot:xlabel='Alkaline_Phosphatase'>

# %%
sns.boxplot(x=data.Alanine_Aminotransferase)
# Out:
# <AxesSubplot:xlabel='Alanine_Aminotransferase'>

# %%
sns.boxplot(x=data.Aspartate_Aminotransferase)
# Out:
# <AxesSubplot:xlabel='Aspartate_Aminotransferase'>

# %%
sns.boxplot(x=data.Total_Protiens)
# Out:
# <AxesSubplot:xlabel='Total_Protiens'>

# %%
sns.boxplot(x=data.Albumin)
# Out:
# <AxesSubplot:xlabel='Albumin'>

# %%
sns.boxplot(x=data.Albumin_and_Globulin_Ratio)
# Out:
# <AxesSubplot:xlabel='Albumin_and_Globulin_Ratio'>

# %% [markdown]
# #### As it contains data of patients where every observation is important hence we will leave the outliers as it is.

# %% [markdown]
# ## Categorical Encoding

# %% [markdown]
# #### We will be using Label encoder to encode gender column

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
data['gender'] = label_encoder.fit_transform(data['gender'])

# %%
data.head()
# Out:
#    age  gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphatase  \
# 0   62       1             10.9               5.5                   699
# 1   62       1              7.3               4.1                   490
# 2   58       1              1.0               0.4                   182
# 3   72       1              3.9               2.0                   195
# 4   46       1              1.8               0.7                   208
#
#    Alanine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        64                         100             7.5
# 1                        60                          68             7.0
# 2                        14                          20             6.8
# 3                        27                          59             7.3
# 4                        19                          14             7.6
#
#    Albumin  Albumin_and_Globulin_Ratio  Target
# 0      3.2                        0.74       1
# ...

# %% [markdown]
# ## Data Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale = MinMaxScaler()
data1 = ['age','Total_Bilirubin','Direct_Bilirubin','Alkaline_Phosphatase','Alanine_Aminotransferase','Aspartate_Aminotransferase',
            'Total_Protiens','Albumin','Albumin_and_Globulin_Ratio']
data[data1] = scale.fit_transform(data[data1])
data.head(15)
# Out:
#          age  gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphatase  \
# 0   0.674419       1         0.140751          0.275510              0.310699
# 1   0.674419       1         0.092493          0.204082              0.208598
# 2   0.627907       1         0.008043          0.015306              0.058134
# 3   0.790698       1         0.046917          0.096939              0.064485
# 4   0.488372       1         0.018767          0.030612              0.070835
# 5   0.255814       0         0.006702          0.005102              0.044455
# 6   0.290698       0         0.006702          0.010204              0.067904
# 7   0.151163       1         0.006702          0.010204              0.067904
# 8   0.593023       1         0.004021          0.005102              0.110894
# 9   0.616279       1         0.002681          0.000000              0.071812
# 10  0.790698       1         0.030831          0.061224              0.096238
# ...

# %% [markdown]
# ### Feature selection using corelation

# %%
data.corr()
# Out:
#                                  age    gender  Total_Bilirubin  \
# age                         1.000000  0.060595         0.012683
# gender                      0.060595  1.000000         0.088272
# Total_Bilirubin             0.012683  0.088272         1.000000
# Direct_Bilirubin            0.008605  0.099227         0.874578
# Alkaline_Phosphatase        0.081465 -0.028870         0.206425
# Alanine_Aminotransferase   -0.086245  0.081485         0.213865
# Aspartate_Aminotransferase -0.019252  0.079592         0.237659
# Total_Protiens             -0.188357 -0.088479        -0.007891
# Albumin                    -0.266721 -0.093450        -0.222148
# Albumin_and_Globulin_Ratio -0.216067 -0.003863        -0.206302
# Target                      0.136218  0.084590         0.220773
#
#                             Direct_Bilirubin  Alkaline_Phosphatase  \
# age                                 0.008605              0.081465
# ...

# %%
plt.figure(figsize = (10,5))
sns.heatmap(data.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Insights
# * Since it is health related no need to drop any column.

# %% [markdown]
# ## Data Splitting

# %%
x = data.drop('Target',axis=1)
y = data['Target']

# %% [markdown]
# ### Splitting data for training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=20)

# %%
x_train.shape
# Out:
# (407, 10)

# %%
x_test.shape
# Out:
# (175, 10)

# %% [markdown]
# ## **Data Modelling**

# %% [markdown]
# #### **Model 1 : Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()
model1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_LR = model1.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.metrics import roc_auc_score,roc_curve

# %%
print('accuracy:', round(accuracy_score(y_test,y_pred_LR),3))
print('recall:', recall_score(y_test,y_pred_LR) )
print('precission:', precision_score(y_test,y_pred_LR))
print('f1_score:', f1_score(y_test,y_pred_LR) )
# Out:
# accuracy: 0.709
# recall: 0.992
# precission: 0.7126436781609196
# f1_score: 0.8294314381270903

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_LR))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_LR).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[  0  50]
#  [  1 124]]
#  True Negative : 0
#  False positive : 50
#  False negative : 1
#  True Positive : 124

# %%
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test, y_pred_LR)
cm_base_model=metrics.confusion_matrix(y_test,y_pred_LR,labels=[0,1])
sns.heatmap(cm_base_model,cmap='Blues',annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ### **Model 2: KNN Classifier**

# %%
from sklearn.neighbors import KNeighborsClassifier
k = 3  # You can adjust the value of k
knn_classifier = KNeighborsClassifier(n_neighbors=k)
knn_classifier.fit(x_train, y_train)
y_pred_KNN = knn_classifier.predict(x_test)

# %%
print('accuracy:', round(accuracy_score(y_test,y_pred_KNN),3))
print('recall:', recall_score(y_test,y_pred_KNN) )
print('precission:', precision_score(y_test,y_pred_KNN))
print('f1_score:', f1_score(y_test,y_pred_KNN) )
# Out:
# accuracy: 0.606
# recall: 0.736
# precission: 0.71875
# f1_score: 0.7272727272727273

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_KNN))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_KNN).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[14 36]
#  [33 92]]
#  True Negative : 14
#  False positive : 36
#  False negative : 33
#  True Positive : 92

# %%
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test, y_pred_KNN)
cm_base_model=metrics.confusion_matrix(y_test,y_pred_KNN,labels=[0,1])
sns.heatmap(cm_base_model,cmap='copper',annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ### **Model 3: SVM Classifier**

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred_SVC = svm.predict(x_test)

# %%
print('accuracy:', round(accuracy_score(y_test,y_pred_SVC),3))
print('recall:', recall_score(y_test,y_pred_SVC) )
print('precission:', precision_score(y_test,y_pred_SVC))
print('f1_score:', f1_score(y_test,y_pred_SVC) )
# Out:
# accuracy: 0.714
# recall: 1.0
# precission: 0.7142857142857143
# f1_score: 0.8333333333333333

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_SVC))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_SVC).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[  0  50]
#  [  0 125]]
#  True Negative : 0
#  False positive : 50
#  False negative : 0
#  True Positive : 125

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred_SVC)
cm_base_model=metrics.confusion_matrix(y_test,y_pred_SVC,labels=[0,1])
sns.heatmap(cm_base_model,cmap='summer',annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ### **Model 4: DecisionTree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(max_depth=4,
                           min_samples_split=5,
                           max_leaf_nodes=10)
dt.fit(x_train,y_train)
y_pred_dt=dt.predict(x_test)

# %%
print('accuracy:', round(accuracy_score(y_test,y_pred_dt),3))
print('recall:', recall_score(y_test,y_pred_dt) )
print('precission:', precision_score(y_test,y_pred_dt))
print('f1_score:', f1_score(y_test,y_pred_dt) )
# Out:
# accuracy: 0.651
# recall: 0.624
# precission: 0.8478260869565217
# f1_score: 0.7188940092165899

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_dt))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_dt).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[36 14]
#  [47 78]]
#  True Negative : 36
#  False positive : 14
#  False negative : 47
#  True Positive : 78

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred_dt)
cm_base_model=metrics.confusion_matrix(y_test,y_pred_dt,labels=[0,1])
sns.heatmap(cm_base_model,cmap='Spectral',annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
params_grid = {
    'max_depth': [None,2,4,6,8,10,12,14,16,18],
    'min_samples_split': [2,4,5,7,8,9,10,12,13,15],
    'min_samples_leaf': [1,2,4,5,7,8,9,10,11,13],
    'max_leaf_nodes':[8,10,11,12,13,14,15,16,17,18]
}

dtm = DecisionTreeClassifier()
grid_search = GridSearchCV(dtm, params_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [None, 2, 4, 6, 8, 10, 12, 14, 16, 18],
#                          'max_leaf_nodes': [8, 10, 11, 12, 13, 14, 15, 16, 17,
#                                             18],
#                          'min_samples_leaf': [1, 2, 4, 5, 7, 8, 9, 10, 11, 13],
#                          'min_samples_split': [2, 4, 5, 7, 8, 9, 10, 12, 13,
#                                                15]},
#              scoring='accuracy')

# %%
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 7, 'min_samples_split': 4}

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(max_depth=None,
                          min_samples_leaf = 7,
                           min_samples_split=4,
                           max_leaf_nodes=10)
dt.fit(x_train,y_train)
y_pred_dt=dt.predict(x_test)

# %%
print('accuracy:', round(accuracy_score(y_test,y_pred_dt),3))
print('recall:', recall_score(y_test,y_pred_dt) )
print('precission:', precision_score(y_test,y_pred_dt))
print('f1_score:', f1_score(y_test,y_pred_dt) )
# Out:
# accuracy: 0.669
# recall: 0.816
# precission: 0.7445255474452555
# f1_score: 0.7786259541984731

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_dt))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_dt).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[ 15  35]
#  [ 23 102]]
#  True Negative : 15
#  False positive : 35
#  False negative : 23
#  True Positive : 102

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred_dt)
cm_base_model=metrics.confusion_matrix(y_test,y_pred_dt,labels=[0,1])
sns.heatmap(cm_base_model,cmap='Spectral',annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ### **Model 4: Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
RF.fit(x_train,y_train)
y_pred_rf=RF.predict(x_test)

# %%
print('accuracy:', round(accuracy_score(y_test,y_pred_rf),3))
print('recall:', recall_score(y_test,y_pred_rf) )
print('precission:', precision_score(y_test,y_pred_rf))
print('f1_score:', f1_score(y_test,y_pred_rf) )
# Out:
# accuracy: 0.697
# recall: 0.84
# precission: 0.7608695652173914
# f1_score: 0.7984790874524714

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_rf))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_rf).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[ 17  33]
#  [ 20 105]]
#  True Negative : 17
#  False positive : 33
#  False negative : 20
#  True Positive : 105

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred_rf)
cm_base_model=metrics.confusion_matrix(y_test,y_pred_rf,labels=[0,1])
sns.heatmap(cm_base_model,cmap='Pastel1',annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ### **Model 5: Navie Bayes Classifier**

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
# Train the classifier on the training data
clf.fit(x_train, y_train)

# Make predictions on the test data
y_pred_clf = clf.predict(x_test)

# %%
print('accuracy:', round(accuracy_score(y_test,y_pred_clf),3))
print('recall:', recall_score(y_test,y_pred_clf) )
print('precission:', precision_score(y_test,y_pred_clf))
print('f1_score:', f1_score(y_test,y_pred_clf) )
# Out:
# accuracy: 0.549
# recall: 0.384
# precission: 0.96
# f1_score: 0.5485714285714286

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_clf))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_clf).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[48  2]
#  [77 48]]
#  True Negative : 48
#  False positive : 2
#  False negative : 77
#  True Positive : 48

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred_clf)
cm_base_model=metrics.confusion_matrix(y_test,y_pred_clf,labels=[0,1])
sns.heatmap(cm_base_model,cmap='Set3',annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ### **Model 6: Gradient Boosting Classifier**

# %%
from xgboost import XGBClassifier
gb=XGBClassifier()
gb.fit(x_train,y_train)
y_pred_gb=gb.predict(x_test)

# %%
print('accuracy:', round(accuracy_score(y_test,y_pred_gb),3))
print('recall:', recall_score(y_test,y_pred_gb) )
print('precission:', precision_score(y_test,y_pred_gb))
print('f1_score:', f1_score(y_test,y_pred_gb) )
# Out:
# accuracy: 0.657
# recall: 0.8
# precission: 0.7407407407407407
# f1_score: 0.7692307692307692

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_gb))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_gb).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[ 15  35]
#  [ 25 100]]
#  True Negative : 15
#  False positive : 35
#  False negative : 25
#  True Positive : 100

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred_gb)
cm_base_model=metrics.confusion_matrix(y_test,y_pred_gb,labels=[0,1])
sns.heatmap(cm_base_model,cmap='BrBG',annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ### **Model 7: XGBoost classifier**

# %%
import xgboost as xgb
from xgboost import XGBClassifier
xgb = XGBClassifier(learning_rate=0.1, n_estimators=100, max_depth=3)

# %%
xgb.fit(x_train, y_train)
y_pred_xgb = xgb.predict(x_test)

# %%
print('accuracy:', round(accuracy_score(y_test,y_pred_xgb),3))
print('recall:', recall_score(y_test,y_pred_xgb) )
print('precission:', precision_score(y_test,y_pred_xgb))
print('f1_score:', f1_score(y_test,y_pred_xgb) )
# Out:
# accuracy: 0.663
# recall: 0.784
# precission: 0.7538461538461538
# f1_score: 0.7686274509803921

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_xgb))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_xgb).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[18 32]
#  [27 98]]
#  True Negative : 18
#  False positive : 32
#  False negative : 27
#  True Positive : 98

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred_xgb)
cm_base_model=metrics.confusion_matrix(y_test,y_pred_xgb,labels=[0,1])
sns.heatmap(cm_base_model,cmap='RdBu',annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ## Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# gridsearch cv
from sklearn.model_selection import GridSearchCV
# define hyperparameter range
param_grid={'C':[0.1,5,10,50,60,70],'gamma':[1,0.1,0.01,0.001,0.001],'random_state':list(range(1,20))}
model=SVC()
grid=GridSearchCV(model,param_grid,verbose=2,scoring="f1",cv=5)
grid.fit(x_train,y_train)

# %%
print(grid.best_params_)

# %%
hyp_svc=SVC(C=5,gamma=1,random_state=1)
hyp_svc.fit(x_train,y_train)

# %%
y_pred_svc=hyp_svc.predict(x_test)

# %%
print('accuracy:', round(accuracy_score(y_test,y_pred_svc),3))
print('recall:', recall_score(y_test,y_pred_svc) )
print('precission:', precision_score(y_test,y_pred_svc))
print('f1_score:', f1_score(y_test,y_pred_svc) )

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred_svc)
cm_base_model=metrics.confusion_matrix(y_test,y_pred_svc,labels=[0,1])
sns.heatmap(cm_base_model,cmap='RdYlGn',annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ## Balancing data

# %%
## balancing the data
data.Target.value_counts()

# %%
 # data is imbalanced and will balance using smote

# %% [markdown]
# ### Smote

# %%
# !pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
#   WARNING: The script f2py.exe is installed in 'C:\Users\Koushik\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Koushik\\AppData\\Roaming\\Python\\Python39\\site-packages\\~umpy.libs\\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll'
# Check the permissions.
# ...
#      ---------------------------------------- 14.9/14.9 MB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.1
#     Uninstalling numpy-1.26.1:
#       Successfully uninstalled numpy-1.26.1

# %%
# Install imblearn package - pip install imblearn
from imblearn.over_sampling import SMOTE
smote = SMOTE()

# %%
# Smote is always applied on train data(x_train and y_train)
x_smote, y_smote = smote.fit_resample(x_train,y_train)

# %% [markdown]
# **Counter** is a container which keeps track to how many times equivalent values are added. Python counter class is a part of collections module and is a subclass of dictionary.

# %%
from collections import Counter
print("Actual Classes",Counter(y_train))
print("SMOTE Classes",Counter(y_smote))
# Out:
# Actual Classes Counter({1: 290, 0: 117})
# SMOTE Classes Counter({1: 290, 0: 290})

# %% [markdown]
# #### **Model 1 : Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()
model1.fit(x_smote,y_smote)
y_pred_LR = model1.predict(x_test)

# %%
print('accuracy:', round(accuracy_score(y_test,y_pred_LR),3))
print('recall:', recall_score(y_test,y_pred_LR) )
print('precission:', precision_score(y_test,y_pred_LR))
print('f1_score:', f1_score(y_test,y_pred_LR) )
# Out:
# accuracy: 0.617
# recall: 0.536
# precission: 0.881578947368421
# f1_score: 0.6666666666666666

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_LR))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_LR).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[41  9]
#  [58 67]]
#  True Negative : 41
#  False positive : 9
#  False negative : 58
#  True Positive : 67

# %% [markdown]
# ### **Model 2: KNN Classifier**

# %%
from sklearn.neighbors import KNeighborsClassifier
k = 3  # You can adjust the value of k
knn_classifier = KNeighborsClassifier(n_neighbors=k)
knn_classifier.fit(x_smote, y_smote)
y_pred_KNN = knn_classifier.predict(x_test)
print('accuracy:', round(accuracy_score(y_test,y_pred_KNN),3))
print('recall:', recall_score(y_test,y_pred_KNN) )
print('precission:', precision_score(y_test,y_pred_KNN))
print('f1_score:', f1_score(y_test,y_pred_KNN) )
# Out:
# accuracy: 0.611
# recall: 0.64
# precission: 0.7766990291262136
# f1_score: 0.7017543859649122

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_KNN))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_KNN).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[27 23]
#  [45 80]]
#  True Negative : 27
#  False positive : 23
#  False negative : 45
#  True Positive : 80

# %% [markdown]
# ### **Model 3: SVM Classifier**

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(x_smote,y_smote)
y_pred_SVC = svm.predict(x_test)
print('accuracy:', round(accuracy_score(y_test,y_pred_SVC),3))
print('recall:', recall_score(y_test,y_pred_SVC) )
print('precission:', precision_score(y_test,y_pred_SVC))
print('f1_score:', f1_score(y_test,y_pred_SVC) )
# Out:
# accuracy: 0.589
# recall: 0.456
# precission: 0.9344262295081968
# f1_score: 0.6129032258064516

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_SVC))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_SVC).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[46  4]
#  [68 57]]
#  True Negative : 46
#  False positive : 4
#  False negative : 68
#  True Positive : 57

# %% [markdown]
# ### **Model 4: Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
RF.fit(x_smote,y_smote)
y_pred_rf=RF.predict(x_test)
print('accuracy:', round(accuracy_score(y_test,y_pred_rf),3))
print('recall:', recall_score(y_test,y_pred_rf) )
print('precission:', precision_score(y_test,y_pred_rf))
print('f1_score:', f1_score(y_test,y_pred_rf) )
# Out:
# accuracy: 0.663
# recall: 0.712
# precission: 0.7946428571428571
# f1_score: 0.7510548523206751

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_rf))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_rf).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[27 23]
#  [36 89]]
#  True Negative : 27
#  False positive : 23
#  False negative : 36
#  True Positive : 89

# %% [markdown]
# ### **Model 5: Navie Bayes Classifier**

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
# Train the classifier on the training data
clf.fit(x_smote, y_smote)
# Make predictions on the test data
y_pred_clf = clf.predict(x_test)
print('accuracy:', round(accuracy_score(y_test,y_pred_clf),3))
print('recall:', recall_score(y_test,y_pred_clf) )
print('precission:', precision_score(y_test,y_pred_clf))
print('f1_score:', f1_score(y_test,y_pred_clf) )
# Out:
# accuracy: 0.554
# recall: 0.392
# precission: 0.9607843137254902
# f1_score: 0.5568181818181819

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_clf))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_clf).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[48  2]
#  [76 49]]
#  True Negative : 48
#  False positive : 2
#  False negative : 76
#  True Positive : 49

# %% [markdown]
# ### **Model 6: Gradient Boosting Classifier**

# %%
from xgboost import XGBClassifier
gb=XGBClassifier()
gb.fit(x_smote,y_smote)
y_pred_gb=gb.predict(x_test)
print('accuracy:', round(accuracy_score(y_test,y_pred_gb),3))
print('recall:', recall_score(y_test,y_pred_gb) )
print('precission:', precision_score(y_test,y_pred_gb))
print('f1_score:', f1_score(y_test,y_pred_gb) )
# Out:
# accuracy: 0.651
# recall: 0.768
# precission: 0.75
# f1_score: 0.7588932806324111

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_pred_gb))
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_gb).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[18 32]
#  [29 96]]
#  True Negative : 18
#  False positive : 32
#  False negative : 29
#  True Positive : 96

# %% [markdown]
# ## ANN

# %%
## model creation
from sklearn.neural_network import MLPClassifier
model = MLPClassifier( hidden_layer_sizes=(50,3),
                       learning_rate_init=0.1,
                       max_iter=100,
                       random_state=2) ## model object creation max_iter=Stopping parameter
model.fit(x_train,y_train) ## training the data
y_predict_proba = model.predict_proba(x_test) ## predicting the pro
## bability of class
y_predict = model.predict(x_test)
y_train_predict = model.predict(x_train)

# %%
print('accuracy:', round(accuracy_score(y_test,y_predict),3))
print('recall:', recall_score(y_test,y_predict) )
print('precission:', precision_score(y_test,y_predict))
print('f1_score:', f1_score(y_test,y_predict) )
# Out:
# accuracy: 0.714
# recall: 1.0
# precission: 0.7142857142857143
# f1_score: 0.8333333333333333

# %%
from sklearn.metrics import confusion_matrix
print("Confusion matrix: \n",confusion_matrix(y_test,y_predict))
tn, fp, fn, tp = confusion_matrix(y_test,y_predict).ravel()

print(" True Negative : %d \n False positive : %d \n False negative : %d \n True Positive : %d \n"%(tn,fp,fn,tp))
# Out:
# Confusion matrix:
#  [[  0  50]
#  [  0 125]]
#  True Negative : 0
#  False positive : 50
#  False negative : 0
#  True Positive : 125

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ### Since the model shows good f1score before smote implementation we will choose the models before smote

# %% [markdown]
# ### SVM model shows highest F1 score with 0.833, hence svm model is the best model to predict whether a person has Liver disease or not
